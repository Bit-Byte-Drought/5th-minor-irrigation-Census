# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# Out:
# C:\Users\Aditya\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df1 = pd.read_csv('../../Datasets/Distribution of Dugwells (in use) According to Constraints in Utilisation of Potential for 5th Minor Irrigation Census (2013-14).csv')

# %%
df1.head()
# Out:
#                 State District  Block/Tehsil         Village  \
# 0  ANDAMAN & NICOBARS  NICOBAR  CAMPBELL BAY    Govind Nagar
# 1  ANDAMAN & NICOBARS  NICOBAR  CAMPBELL BAY  Joginder Nagar
# 2  ANDAMAN & NICOBARS  NICOBAR  CAMPBELL BAY   Sashtri Nagar
# 3  ANDAMAN & NICOBARS  NICOBAR   CAR NICOBAR      Big Lapati
# 4  ANDAMAN & NICOBARS  NICOBAR   CAR NICOBAR     Chuckchucha
#
#    No. of Dugwells in use  No.of Dugwells without constraints   \
# 0                       7                                    7
# 1                       8                                    8
# 2                       5                                    5
# 3                       7                                    7
# 4                      19                                   19
#
#    No. of Dugwell Having Constraints in utillsation of potential - Non Availability of Adequate Power  \
# 0                                                  0
# 1                                                  0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226052 entries, 0 to 226051
# Data columns (total 12 columns):
#  #   Column                                                                                              Non-Null Count   Dtype
# ---  ------                                                                                              --------------   -----
#  0   State                                                                                               226052 non-null  object
#  1   District                                                                                            226052 non-null  object
#  2   Block/Tehsil                                                                                        226052 non-null  object
#  3   Village                                                                                             226052 non-null  object
# ...

# %%
df1.shape
# Out:
# (226052, 12)

# %%
df1['State'].value_counts()
# Out:
# MADHYA PRADESH        42868
# MAHARASHTRA           37407
# ODISHA                27912
# RAJASTHAN             25689
# JHARKHAND             23846
# TAMIL NADU            13884
# GUJARAT               13641
# KARNATAKA              8201
# ANDHRA PRADESH         6861
# UTTAR PRADESH          6296
# TELENGANA              6175
# CHHATISGARH            5229
# BIHAR                  3777
# WEST BENGAL            2185
# KERALA                  971
# GOA                     324
# HIMACHAL PRADESH        202
# ANDAMAN & NICOBARS      183
# ASSAM                   136
# UTTARAKHAND             102
# TRIPURA                  38
# JAMMU & KASHMIR          35
# MEGHALAYA                26
# HARYANA                  21
# ARUNACHAL PRADESH        21
# PUDUCHERRY               13
# NAGALAND                  9
# Name: State, dtype: int64

# %%
MP = df1[df1['State'] == 'MADHYA PRADESH']

# %%
MP.drop(columns = ['State'])
# Out:
#           District Block/Tehsil         Village  No. of Dugwells in use  \
# 63448   Agar Malwa         Agar           Aavar                      76
# 63449   Agar Malwa         Agar        abhaypur                      38
# 63450   Agar Malwa         Agar  Agar bheempura                      19
# 63451   Agar Malwa         Agar    Agar chhavni                       8
# 63452   Agar Malwa         Agar      Ahirbardia                      60
# ...            ...          ...             ...                     ...
# 106311     vidisha      vidisha           THARR                      72
# 106312     vidisha      vidisha           TILAK                      40
# 106313     vidisha      vidisha       TILAKHEDI                       2
# 106314     vidisha      vidisha        UDAIGIRI                       4
# 106315     vidisha      vidisha         VIDISHA                      17
#
#         No.of Dugwells without constraints   \
# 63448                                    75
# ...

# %%
MP['District'].value_counts()
# Out:
# SAGAR          2017
# Chhindwara     1807
# Rajgarh        1613
# Satna          1480
# Seoni          1476
# KHARGONE       1387
# BETUL          1361
# vidisha        1284
# DHAR           1210
# Shivpuri       1122
# GUNA           1074
# Ujjain         1072
# DAMOH          1071
# Dewas          1039
# Sehore         1037
# REWA            995
# Ratlam          993
# Tikamgarh       987
# Mandsaur        938
# BALAGHAT        900
# Raisen          894
# JABALPUR        872
# SIDHI           860
# Chhatarpur      860
# Katni           821
# Neemuch         797
# HOSHANGABAD     757
# Jhabua          732
# khandwa         725
# Ashoknagar      718
# SHAHDOL         715
# Datia           649
# SINGRAULI       629
# shajapur        621
# Indore          617
# BARWANI         604
# Mandla          564
# Bhind           555
# Alirajpur       512
# Agar Malwa      500
# Gwalior         483
# Panna           475
# Morena          467
# HARDA           465
# BHOPAL          427
# ...

# %%
sb.kdeplot(df1['No. of Dugwells in use'],shade=True)
